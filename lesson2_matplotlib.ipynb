# %% [markdown]
# <a href="https://colab.research.google.com/github/WWCode-SV/Python_for_Data_Analysis/blob/master/lesson2_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Visualization.. Matplotlib, Seaborn,Plotly(out of scope for this course: https://plot.ly/).
#
# > Indented block

# %% [markdown]
# Why learning Matplotlib is important
# - With little code to be able to present data in clear and concise way.
# - Able to visualize data to see patterns.
# -Provides a lot of built in functionalities like barplot, histograms etc.
#
# Tutorial: https://matplotlib.org/users/pyplot_tutorial.html
#
# Documentation: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.html
#
# More information: https://realpython.com/python-matplotlib-guide/

# %%
import matplotlib.pyplot as plt    #import the library

# %% [markdown]
# Matplotlib is very orthogonal. It does the plotting in on the plot.

# %%
X = range(100)    #numbers from 0 to 99
y = [x ** 2 for x in X]   #squared values of X

print(X)
print(y)
# Out:
# range(0, 100)
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604, 9801]

# %%
plt.plot(X,y)
plt.xlabel("Range X")
plt.ylabel("Squared of X")
plt.show()            #prints the plot

# %% [markdown]
# **Lab:** import matplotlib.pyplot as plt
# X = [1,2,3,4,5]
# y = [5,10,15,20]
#
# plt.plot(X, y, linestyle="dashed", marker="o", color="green")
# print the plot.

# %%
#Basic Liine plot

time = [1,2,3,4,5,6]
revenue = [200,250,300,350,400,450]
cost  = [100,110,115,120,125,130]

plt.xlabel("in months")
plt.ylabel("in months")

plt.title("Time, Revenue and Costs")


plt.plot(time,revenue)
plt.plot(time,cost)

plt.legend(['Revenue','Cost'], loc=5)  #takes in a list , loc- location
plt.show()

# %%
time = [0, 1, 2, 3, 4]
revenue = [200, 400, 650, 800, 850]
costs = [150, 500, 550, 550, 560]

plt.plot(time,revenue,color="purple",
        linestyle="--")

plt.plot(time,costs,color="#82edc9",
        marker='s')

plt.show()

# %% [markdown]
# plt.axis - used to zoom into a particular section.
# We feed in the list of min x-value, max x-value, min y-value, max y-value. Also can be max x-value, min x-value, max y-value, min y-value.

# %%
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]
plt.plot(x, y)
plt.axis([0, 3, 2, 5])
plt.show()

# %% [markdown]
# SUBPLOTS

# %%
# Data sets
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

# First Subplot
plt.subplot(1, 2, 1)
plt.plot(x, y, color='green')
plt.title('First Subplot')

# Second Subplot
plt.subplot(1, 2, 2)
plt.plot(x, y, color='steelblue')
plt.title('Second Subplot')

# Display both subplots
plt.show()

# %%
#setting ticks for line plots

from matplotlib import pyplot as plt

month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep","Oct", "Nov", "Dec"]

months = range(12)
conversion = [0.05, 0.08, 0.18, 0.28, 0.4, 0.66, 0.74, 0.78, 0.8, 0.81, 0.85, 0.85]

plt.xlabel("Months")
plt.ylabel("Conversion")

plt.plot(months, conversion)

ax=plt.subplot()
ax.set_xticks(months)
ax.set_xticklabels(month_names)
ax.set_yticks([0.10, 0.25, 0.5, 0.75])
ax.set_yticklabels(["10%","25%","50%","75%"])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %% [markdown]
# Plot figures.

# %%
from matplotlib import pyplot as plt

word_length = [8, 11, 12, 11, 13, 12, 9, 9, 7, 9]
power_generated = [753.9, 768.8, 780.1, 763.7, 788.5, 782, 787.2, 806.4, 806.2, 798.9]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]
plt.close('all')
plt.plot(years,word_length)
#plt.figure() to create new figures and size them how we want.
#We can add the keyword figsize=(width, height) to set the size of the figure, in inches. We use parentheses (( and )) to pass in the width and height, which are separated by a comma (,).
plt.figure(figsize=(7,3))
plt.plot(years,power_generated)
plt.savefig('power_generated.png')
plt.show()

# %% [markdown]
# Simple Bar Chart

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales =  [91, 76, 56, 66, 52, 27]
x_values=range(len(drinks))
plt.bar(x_values,sales)
plt.show()

# %%
#Stacked Bars
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 =  [91, 76, 56, 66, 52, 27]
sales2 = [65, 82, 36, 68, 38, 40]
  
plt.bar(range(len(drinks)), sales1)
plt.bar(range(len(drinks)), sales2, bottom=sales1)

plt.legend(["Location 1", "Location 2"])

plt.show()

# %%
#Pie charts

payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

plt.pie(payment_method_freqs,autopct='%0.1f%%')
plt.axis('equal')
plt.legend(payment_method_names)
plt.show()
