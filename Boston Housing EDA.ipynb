# %% [markdown]
# ## Boston Housing Dataset
# #### WWC-SV Python for Data Analysis Series

# %% [raw]
# This dataset contains information collected by the U.S Census Service concerning housing in the area of Boston Mass. It was obtained from the StatLib archive (http://lib.stat.cmu.edu/datasets/boston), and has been used extensively throughout the literature to benchmark algorithms. However, these comparisons were primarily done outside of Delve and are thus somewhat suspect. The dataset is small in size with only 506 cases.
#
# The data was originally published by Harrison, D. and Rubinfeld, D.L. `Hedonic prices and the demand for clean air', J. Environ. Economics & Management, vol.5, 81-102, 1978.

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
#Load dataset from sklearn
import sklearn
from sklearn.datasets import load_boston
boston=load_boston()

# %%
#Load data into pandas dataframe
boston_df=pd.DataFrame(boston.data, columns=boston.feature_names)
boston_df['medv']=boston.target

# %% [markdown]
# ### EDA

# %%
#review datapoints
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# #### Data Description

# %% [raw]
# The Boston data frame has 506 rows and 14 columns.
#
# This data frame contains the following columns:
#
# crim : per capita crime rate by town.
# zn : proportion of residential land zoned for lots over 25,000 sq.ft.
# indus : proportion of non-retail business acres per town.
# chas : Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# nox : nitrogen oxides concentration (parts per 10 million).
# rm : average number of rooms per dwelling.
# age : proportion of owner-occupied units built prior to 1940.
# dis : weighted mean of distances to five Boston employment centres.
# rad : index of accessibility to radial highways.
# tax : full-value property-tax rate per $10,000.
# ptratio : pupil-teacher ratio by town.
# black : 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
# lstat : lower status of the population (percent).
# medv : median value of owner-occupied homes in $1000s.

# %%
boston_df.shape
# Out:
# (506, 14)

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# medv       506 non-null float64
# dtypes: float64(14)
# memory usage: 55.4 KB

# %% [raw]
# There are no null values in the dataset. All fields were loaded as float64.
# We have 506 rows of data with 13 predictors. All data points are numeric except for Charles River Dummy Variable and Index of accessibility to radial highways(point for discussion).

# %% [markdown]
# ##### 1. Plot distribution of Value of Owner-occupied homes.

# %%
sns.distplot(boston_df['medv'])
plt.show()

# %% [raw]
# The distribution shows range of medv from 5k to 50k spiking at 20k. There is a spike at 50k. Where does that originate? What is the cause for the spike?

# %% [markdown]
# ##### 2. What proportion of the dataset is bound by the Charles River?

# %%
boston_df['CHAS'].value_counts()
# Out:
# 0.0    471
# 1.0     35
# Name: CHAS, dtype: int64

# %% [markdown]
# ##### 3. Review datapoints that create the right tail at medv=50

# %%
boston_df[boston_df['medv']==50]
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS   RAD    TAX  \
# 161  1.46336   0.0  19.58   0.0  0.6050  7.489   90.8  1.9709   5.0  403.0
# 162  1.83377   0.0  19.58   1.0  0.6050  7.802   98.2  2.0407   5.0  403.0
# 163  1.51902   0.0  19.58   1.0  0.6050  8.375   93.9  2.1620   5.0  403.0
# 166  2.01019   0.0  19.58   0.0  0.6050  7.929   96.2  2.0459   5.0  403.0
# 186  0.05602   0.0   2.46   0.0  0.4880  7.831   53.6  3.1992   3.0  193.0
# 195  0.01381  80.0   0.46   0.0  0.4220  7.875   32.0  5.6484   4.0  255.0
# 204  0.02009  95.0   2.68   0.0  0.4161  8.034   31.9  5.1180   4.0  224.0
# 225  0.52693   0.0   6.20   0.0  0.5040  8.725   83.0  2.8944   8.0  307.0
# 257  0.61154  20.0   3.97   0.0  0.6470  8.704   86.9  1.8010   5.0  264.0
# 267  0.57834  20.0   3.97   0.0  0.5750  8.297   67.0  2.4216   5.0  264.0
# 283  0.01501  90.0   1.21   1.0  0.4010  7.923   24.8  5.8850   1.0  198.0
# ...

# %%
boston_df[boston_df['medv']==50].shape
# Out:
# (16, 14)

# %% [raw]
# There are 16 datapoints at medv 50k. 5 of these datapoints have RAD at 24 and PTRATIO at 20.2.
# We have to further investigate why there is a spkie at 50k.

# %% [markdown]
# ##### 4. Does average number of rooms per dwelling have a linear relationship with median value of owner-occupied homes. Use visualization to determine.

# %%
sns.regplot(x="RM",y="medv", data=boston_df)
plt.show()

# %% [raw]
# As expected,RM has a strong correlation with medv.

# %% [markdown]
# ##### 5. Find 3 good predictors for mdev. Use visualization to observe linear relationship.

# %%
sns.pairplot(boston_df)
plt.show()

# %%
sns.regplot(x="DIS",y="medv", data=boston_df)
plt.show()

# %%
sns.regplot(x="AGE",y="medv", data=boston_df)
plt.show()

# %%
sns.regplot(x="INDUS",y="medv", data=boston_df)
plt.show()

# %%
sns.regplot(x="LSTAT",y="medv", data=boston_df)
plt.show()

# %%
#Review correlations to identify linear relationships
corr=boston_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
#         <style  type="text/css" >
#
#
#             #T_1f2413c6_bf87_11e9_9a2b_08d40ce62a84row0_col0 {
#
#                 background-color:  #b40426;
#
#             }
#
#             #T_1f2413c6_bf87_11e9_9a2b_08d40ce62a84row0_col1 {
#
#                 background-color:  #88abfd;
#
#             }
#
#             #T_1f2413c6_bf87_11e9_9a2b_08d40ce62a84row0_col2 {
#
#                 background-color:  #f6bda2;
#
#             }
#
#             #T_1f2413c6_bf87_11e9_9a2b_08d40ce62a84row0_col3 {
#
#                 background-color:  #4c66d6;
#
#             }
#
#             #T_1f2413c6_bf87_11e9_9a2b_08d40ce62a84row0_col4 {
#
#                 background-color:  #f7b79b;
#
#             }
#
#             #T_1f2413c6_bf87_11e9_9a2b_08d40ce62a84row0_col5 {
#
#                 background-color:  #8badfd;
#
#             }
#
#             #T_1f2413c6_bf87_11e9_9a2b_08d40ce62a84row0_col6 {
#
#                 background-color:  #f5c4ac;
#
#             }
#
# ...
