# %% [markdown]
# #Week 1: Introduction, Data Analysis (Numpy/Pandas)

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ###Pandas is widely used for loading data files into memory and feeding into Machine Learning models. It stores data sets in dataframe format which are easy to manipulate and perform EDA.

# %%
#importing libraries
import pandas as pd

# %% [markdown]
# ###Should be replaced with the path and name of your files.

# %%
#load dataset
train = pd.read_csv(r"/content/gdrive/My Drive/Python for Data Analysis Data Science/Titanic Survival Prediction Project/data/train.csv")
test = pd.read_csv(r"/content/gdrive/My Drive/Python for Data Analysis Data Science/Titanic Survival Prediction Project/data/train.csv")

# %% [markdown]
# ###Let’s make a copy of train and test data so that even if we have to make any changes in these datasets we would not lose the original datasets.

# %%
train_original = train.copy() 
test_original = test.copy()

# %% [markdown]
# ###Understanding the Data

# %%
# Firstly, we will check the features present in our data
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Column data types
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Shape of the train dataset
train.shape
# Out:
# (891, 12)

# %%
#Shape of the train dataset
test.shape
# Out:
# (891, 12)

# %%
#to see snapshot of data
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
#info method to output some general information about the dataframe
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
#describe method shows basic statistical characteristics of each numerical feature, we will understand how these factors affect the model performance when we cover statistics
train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
#we can see categories of data for positive and negative classes
train.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
#we can use filter to select particular columns in data
train.filter(["Name", "Sex", "Age"]).head()
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
#categorical to numeric conversion
pd.get_dummies(train, columns=["Sex"]).head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked  Sex_female  Sex_male
# 0            1         0       3  ...        S           0         1
# 1            2         1       1  ...        C           1         0
# 2            3         1       3  ...        S           1         0
# 3            4         1       1  ...        S           1         0
# 4            5         0       3  ...        S           0         1
#
# [5 rows x 13 columns]

# %%
#normalization

# %%
#scaling

# %%
#to apply functions to each column, use apply()

# %%
#resources to practice
#https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset

# %% [markdown]
# #Week 2: Data Visualization (Matplotlib/Seaborn)
# - Next week we will do univariate analysis and bivariate analysis using data visualization to getter better picture about data and how it is inter related.

# %% [markdown]
# #Week 3: Descriptive Statistics
# - Missing value imputation

# %% [markdown]
# #Week 4: Inferential Statistics
# - Feature Engineering

# %% [markdown]
# #Week 5: Data preprocessing for modeling.
# - Other aspects of EDA for feeding meaningful data to ML models.
