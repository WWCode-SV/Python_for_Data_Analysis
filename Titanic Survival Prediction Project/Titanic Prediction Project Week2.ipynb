# %% [markdown]
# #Week 1: Introduction, Data Analysis (Numpy/Pandas)

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ###Pandas is widely used for cleaning preprocessing data before feeding into Machine Learning models. It stores data sets in dataframe format which are easy to manipulate and perform EDA.

# %%
#importing libraries
import pandas as pd

# %% [markdown]
# ###Should be replaced with the path and name of your files.

# %%
#load dataset
train = pd.read_csv(r"/content/gdrive/My Drive/Python for Data Analysis Data Science/Titanic Survival Prediction Project/data/train.csv")
test = pd.read_csv(r"/content/gdrive/My Drive/Python for Data Analysis Data Science/Titanic Survival Prediction Project/data/test.csv")

# %% [markdown]
# ###Let’s make a copy of train and test data so that even if we have to make any changes in these datasets we would not lose the original datasets.

# %%
train_original = train.copy() 
test_original = test.copy()

# %% [markdown]
# ###Understanding the Data

# %%
# check the features present in our data
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#column data types
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#shape of the train dataset
train.shape
# Out:
# (891, 12)

# %%
#shape of the test dataset
test.shape
# Out:
# (418, 11)

# %%
#to see snapshot of data
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
#info method to output some general information about the dataframe
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
#describe method shows basic statistical characteristics of each numerical feature, we will understand how these factors affect the model performance when we cover statistics
train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
#we can see categories of data for positive and negative classes
train.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
#we can use filter to select particular columns in data
train.filter(["Name", "Sex", "Age"]).head()
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %% [markdown]
# ###There are various other functions like map and lambda which you can explore

# %%
#to see unique values of a feature
train.Cabin.unique()
train.Ticket.unique()
train.Parch.unique()
train.SibSp.unique()
train.Embarked.unique()
train.Age.unique()
train.Pclass.unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# #Week 2: Data Visualization (Matplotlib/Seaborn)
# - Will see how to do univariate analysis and bivariate analysis using data visualization to getter better picture about data and how it is inter related.

# %% [markdown]
# ##Univariate Analysis
#
# - It is the simplest form of analyzing data where we examine each variable individually.
# - For categorical features we can use frequency table or bar plots which will calculate the number of each category in a particular variable.
# - For numerical features, probability density plots can be used to look at the distribution of the variable.

# %% [markdown]
# ###target variable - survived

# %%
train['Survived'].value_counts().plot.bar()

# %%
train['Survived'].value_counts().plot.bar(figsize=(8,6), title= 'Survived')

# %%
train['Pclass'].value_counts().plot.bar(figsize=(8,6), title= 'Pclass')

# %%
train['Sex'].value_counts().plot.bar(figsize=(8,6), title= 'Sex')

# %%
train['SibSp'].value_counts().plot.bar(figsize=(8,6), title= 'SibSp')

# %%
train['Parch'].value_counts().plot.bar(figsize=(8,6), title= 'Parch')

# %%
train['Cabin'].value_counts().plot.bar(figsize=(8,6), title= 'Cabin')

# %%
train['Embarked'].value_counts().plot.bar(figsize=(8,6), title= 'Embarked')

# %%
train['PassengerId'].value_counts().plot.bar(figsize=(8,6), title= 'PassengerId')

# %%
train['Name'].value_counts().plot.bar(figsize=(8,6), title= 'Name')

# %%
train['Ticket'].value_counts().plot.bar(figsize=(8,6), title= 'Ticket')

# %%
train['Age'].value_counts().plot.bar(figsize=(8,6), title= 'Age')

# %%
train['Fare'].value_counts().plot.bar(figsize=(8,6), title= 'Fare')

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #heatmap using seaborn

# %% [markdown]
# #Bivariate Analysis
# - After looking at every variable individually in univariate analysis, we will now explore them again with respect to the target variable.

# %%
Sex = pd.crosstab(train['Sex'],train['Survived'])
Sex.div(Sex.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
Pclass = pd.crosstab(train['Pclass'],train['Survived'])
Pclass.div(Pclass.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
SibSp = pd.crosstab(train['SibSp'],train['Survived'])
SibSp.div(SibSp.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
Age = pd.crosstab(train['Age'],train['Survived'])
Age.div(Age.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
Embarked = pd.crosstab(train['Embarked'],train['Survived'])
Embarked.div(Embarked.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
Parch = pd.crosstab(train['Parch'],train['Survived'])
Parch.div(Parch.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(8,8))

# %% [markdown]
# - Random Forests and other ensemble methods are excellent models for some data science tasks, particularly some classification tasks.
#
# - These methods are most often used for prediction, but looking at the feature importances can give you a sense of which of your variables have the most effect in these models. You can use that information to engineer new features, drop out features that look like noise, or just to inform you as you continue building models.

# %%
## Import the random forest model.
from sklearn.ensemble import RandomForestClassifier 
## This line instantiates the model. 
rf = RandomForestClassifier() 
X_train_to_fit
# Out:
#    Pclass   Age  SibSp  Parch  ...  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0       3  22.0      1      0  ...         1           0           0           1
# 1       1  38.0      1      0  ...         0           1           0           0
# 2       3  26.0      0      0  ...         0           0           0           1
# 3       1  35.0      1      0  ...         0           0           0           1
# 4       3  35.0      0      0  ...         1           0           0           1
#
# [5 rows x 10 columns]

# %%
## Fit the model on your training data.
print(X_train_to_fit.shape)
rf.fit(X_train_to_fit, y_train) 
## And score it on your testing data.
#rf.score(X_test, y_test)

import pandas as pd
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                   columns=['importance']).sort_values('importance', 
                                   ascending=False)
# Out:
# (5, 10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-c7fe8f335794> in <module>()
#       1 print(X_train_to_fit.shape)
# ----> 2 rf.fit(X_train_to_fit, y_train)
#       3 ## And score it on your testing data.
#       4 #rf.score(X_test, y_test)
#       5
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# ...

# %%
#Fitting Model

# %% [markdown]
# #Fitting Model

# %%
#import
import sklearn

#Creating train and test dataset
X = train.drop(['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin'], axis=1)
y = train['Survived']

#categorical to numerical
#pd.concat([X, pd.get_dummies(X["Sex", "Embarked"])], axis=1)

pd.get_dummies((['Sex', 'Survived', 'Name', 'Ticket', 'Cabin'], axis=1))
print(X.shape)
print(X.head())

#train test split
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Sex', 'Embarked')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-e4af3d856c32> in <module>()
#       6
# ...
